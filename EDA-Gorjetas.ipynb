# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/tips_atualizado.csv')
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill' : 'valor_conta', 
    'tip' : 'gorjeta', 
    'dessert': 'sobremesa', 
    'day': 'dia_semana', 
    'time' : 'hora_do_dia', 
    'size' : 'total_de_pessoas'
}

# %%
gorjeta = dados.rename(columns = renomear)

# %%
gorjeta
# Out:
#       valor_conta   gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas
# 0       16.990000  1.010000        No        Sun      Dinner                 2
# 1       10.340000  1.660000        No        Sun      Dinner                 3
# 2       21.010000  3.500000        No        Sun      Dinner                 3
# 3       23.680000  3.310000        No        Sun      Dinner                 2
# 4       24.590000  3.610000        No        Sun      Dinner                 4
# ...           ...       ...       ...        ...         ...               ...
# 3411    26.330845  4.729032        No        Sat      Dinner                 3
# 3412    25.531567  1.604021       Yes        Sat      Dinner                 2
# 3413    21.547132  1.733914       Yes        Sat      Dinner                 2
# 3414    18.966233  1.718951        No        Sat      Dinner                 2
# 3415    18.079740  2.812176        No       Thur      Dinner                 2
#
# [3416 rows x 6 columns]

# %%
gorjeta.sobremesa.unique() #verifica os valores únicos do campo
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No' : 'Não', 
    'Yes' : 'Sim'
}

# %%
gorjeta.sobremesa = gorjeta.sobremesa.map(sim_nao)

# %%
gorjeta
# Out:
#       valor_conta   gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas
# 0       16.990000  1.010000       Não        Sun      Dinner                 2
# 1       10.340000  1.660000       Não        Sun      Dinner                 3
# 2       21.010000  3.500000       Não        Sun      Dinner                 3
# 3       23.680000  3.310000       Não        Sun      Dinner                 2
# 4       24.590000  3.610000       Não        Sun      Dinner                 4
# ...           ...       ...       ...        ...         ...               ...
# 3411    26.330845  4.729032       Não        Sat      Dinner                 3
# 3412    25.531567  1.604021       Sim        Sat      Dinner                 2
# 3413    21.547132  1.733914       Sim        Sat      Dinner                 2
# 3414    18.966233  1.718951       Não        Sat      Dinner                 2
# 3415    18.079740  2.812176       Não       Thur      Dinner                 2
#
# [3416 rows x 6 columns]

# %%
gorjeta.dia_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
semana = {
    'Sun' : 'Dom', 
    'Sat' : 'Sáb', 
    'Thur' : 'Qui', 
    'Fri' : 'Sex'
}

# %%
gorjeta.dia_semana = gorjeta.dia_semana.map(semana)
gorjeta
# Out:
#       valor_conta   gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas
# 0       16.990000  1.010000       Não        Dom      Dinner                 2
# 1       10.340000  1.660000       Não        Dom      Dinner                 3
# 2       21.010000  3.500000       Não        Dom      Dinner                 3
# 3       23.680000  3.310000       Não        Dom      Dinner                 2
# 4       24.590000  3.610000       Não        Dom      Dinner                 4
# ...           ...       ...       ...        ...         ...               ...
# 3411    26.330845  4.729032       Não        Sáb      Dinner                 3
# 3412    25.531567  1.604021       Sim        Sáb      Dinner                 2
# 3413    21.547132  1.733914       Sim        Sáb      Dinner                 2
# 3414    18.966233  1.718951       Não        Sáb      Dinner                 2
# 3415    18.079740  2.812176       Não        Qui      Dinner                 2
#
# [3416 rows x 6 columns]

# %%
gorjeta.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
horario = {
    'Dinner': 'Jantar', 
    'Lunch' : 'Almoço'
}

# %%
gorjeta.hora_do_dia = gorjeta.hora_do_dia.map(horario)
gorjeta
# Out:
#       valor_conta   gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas
# 0       16.990000  1.010000       Não        Dom      Jantar                 2
# 1       10.340000  1.660000       Não        Dom      Jantar                 3
# 2       21.010000  3.500000       Não        Dom      Jantar                 3
# 3       23.680000  3.310000       Não        Dom      Jantar                 2
# 4       24.590000  3.610000       Não        Dom      Jantar                 4
# ...           ...       ...       ...        ...         ...               ...
# 3411    26.330845  4.729032       Não        Sáb      Jantar                 3
# 3412    25.531567  1.604021       Sim        Sáb      Jantar                 2
# 3413    21.547132  1.733914       Sim        Sáb      Jantar                 2
# 3414    18.966233  1.718951       Não        Sáb      Jantar                 2
# 3415    18.079740  2.812176       Não        Qui      Jantar                 2
#
# [3416 rows x 6 columns]

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.11.1
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: /home/jose/anaconda_/envs/alura_pandas/lib/python3.8/site-packages
# Requires: matplotlib, scipy, numpy, pandas
# Required-by:

# %%
valor_gorjeta = sns.scatterplot(x = 'valor_conta', y = 'gorjeta', data = gorjeta)

# %%
gorjeta.shape[0]
# Out:
# 3416

# %%
gorjeta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3416 entries, 0 to 3415
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   valor_conta       3416 non-null   float64
#  1   gorjeta           3416 non-null   float64
#  2   sobremesa         3416 non-null   object
#  3   dia_semana        3416 non-null   object
#  4   hora_do_dia       3416 non-null   object
#  5   total_de_pessoas  3416 non-null   int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 160.2+ KB

# %%
gorjeta.count()
# Out:
# valor_conta         3416
# gorjeta             3416
# sobremesa           3416
# dia_semana          3416
# hora_do_dia         3416
# total_de_pessoas    3416
# dtype: int64

# %%
gorjeta['porcentagem'] = ((gorjeta['gorjeta'] / gorjeta['valor_conta'])*100).round(1)

# %%
gorjeta
# Out:
#       valor_conta   gorjeta sobremesa dia_semana hora_do_dia  \
# 0       16.990000  1.010000       Não        Dom      Jantar
# 1       10.340000  1.660000       Não        Dom      Jantar
# 2       21.010000  3.500000       Não        Dom      Jantar
# 3       23.680000  3.310000       Não        Dom      Jantar
# 4       24.590000  3.610000       Não        Dom      Jantar
# ...           ...       ...       ...        ...         ...
# 3411    26.330845  4.729032       Não        Sáb      Jantar
# 3412    25.531567  1.604021       Sim        Sáb      Jantar
# 3413    21.547132  1.733914       Sim        Sáb      Jantar
# 3414    18.966233  1.718951       Não        Sáb      Jantar
# 3415    18.079740  2.812176       Não        Qui      Jantar
#
#       total_de_pessoas  porcentagem
# 0                    2          5.9
# 1                    3         16.1
# 2                    3         16.7
# 3                    2         14.0
# 4                    4         14.7
# ...

# %%
valor_porcentagem = sns.scatterplot(x = 'valor_conta', y = 'porcentagem', data = gorjeta)

# %%
valor_porcentagem_linha = sns.relplot(x = 'valor_conta', y = 'porcentagem', kind = 'line', data = gorjeta)

# %%
grafico = sns.lmplot(x = 'valor_conta', y = 'porcentagem', data = gorjeta).set_titles('teste')

# %% [markdown]
# ## Análise II - sobremesa

# %%
gorjeta.head()
# Out:
#    valor_conta  gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas  \
# 0        16.99     1.01       Não        Dom      Jantar                 2
# 1        10.34     1.66       Não        Dom      Jantar                 3
# 2        21.01     3.50       Não        Dom      Jantar                 3
# 3        23.68     3.31       Não        Dom      Jantar                 2
# 4        24.59     3.61       Não        Dom      Jantar                 4
#
#    porcentagem
# 0          5.9
# 1         16.1
# 2         16.7
# 3         14.0
# 4         14.7

# %%
gorjeta[gorjeta.sobremesa == 'Sim'].describe()
# Out:
#        valor_conta      gorjeta  total_de_pessoas  porcentagem
# count  1302.000000  1302.000000       1302.000000  1302.000000
# mean     20.800076     2.710137          2.408602    15.349770
# std       9.901358     1.162280          0.806690     8.908388
# min       2.799644     0.766203          1.000000     2.100000
# 25%      13.495501     1.911661          2.000000     9.300000
# 50%      17.917059     2.434354          2.000000    14.700000
# 75%      26.807493     3.326298          3.000000    18.900000
# max      55.804318    10.000000          5.000000    81.300000

# %%
gorjeta[gorjeta.sobremesa == 'Não'].describe()
# Out:
#        valor_conta      gorjeta  total_de_pessoas  porcentagem
# count  2114.000000  2114.000000       2114.000000  2114.000000
# mean     19.223436     2.711837          2.668874    15.005440
# std       8.316030     1.024271          1.014848     4.420583
# min       6.533329     0.910509          1.000000     4.200000
# 25%      13.281977     1.931135          2.000000    12.100000
# 50%      17.736923     2.608222          2.000000    14.600000
# 75%      22.749482     3.284578          3.000000    17.800000
# max      53.091371     9.000000          6.000000    33.500000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=gorjeta)

# %%
sns.relplot(x='valor_conta', y='gorjeta', hue='sobremesa', data=gorjeta)

# %%
sns.relplot(x='valor_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjeta)

# %%
sns.lmplot(x='valor_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjeta)

# %%
sns.lmplot(x='valor_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjeta)

# %%
sns.relplot(x='valor_conta', y='porcentagem', col='sobremesa', hue='sobremesa', kind='line', data=gorjeta)

# %% [markdown]
#  ## Teste de hipótese
#
#  **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é a mesma nos dois grupos**
#
#  **H<sup>alt</sup>**
# > **A distribuição da taxa da gorjeta não é a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjeta.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjeta.query("sobremesa == 'Não'").porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.0359865647696579

# %%
gorjeta.head()
# Out:
#    valor_conta  gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas  \
# 0        16.99     1.01       Não        Dom      Jantar                 2
# 1        10.34     1.66       Não        Dom      Jantar                 3
# 2        21.01     3.50       Não        Dom      Jantar                 3
# 3        23.68     3.31       Não        Dom      Jantar                 2
# 4        24.59     3.61       Não        Dom      Jantar                 4
#
#    porcentagem
# 0          5.9
# 1         16.1
# 2         16.7
# 3         14.0
# 4         14.7

# %%
sns.catplot(y='valor_conta', x='dia_semana', data = gorjeta)

# %%
sns.relplot(x='valor_conta', y='gorjeta', hue='dia_semana', data=gorjeta)

# %%
sns.relplot(x='valor_conta', y='porcentagem', hue='dia_semana', data=gorjeta)

# %%
sns.relplot(x='valor_conta', y='gorjeta', hue='dia_semana', col='dia_semana', data=gorjeta)

# %%
sns.relplot(x='valor_conta', y='porcentagem', hue='dia_semana', col='dia_semana', data=gorjeta)

# %%
sns.lmplot(x='valor_conta', y='porcentagem', hue='dia_semana', col='dia_semana', data=gorjeta)

# %%
media_geral_gorjetas = gorjeta.gorjeta.mean().round(3)

# %%
print(f'A média geral das gorjetas é de {media_geral_gorjetas}')
# Out:
# A média geral das gorjetas é de 2.711

# %%
gorjeta.groupby(['dia_semana']).mean()[['valor_conta', 'gorjeta', 'porcentagem']]
# Out:
#             valor_conta   gorjeta  porcentagem
# dia_semana
# Dom           21.439133  2.902079    15.499906
# Qui           17.724088  2.556177    15.422696
# Sex           17.215616  2.549960    16.316917
# Sáb           20.480249  2.690114    14.357800

# %%
gorjeta.dia_semana.value_counts()
# Out:
# Sáb    1218
# Dom    1064
# Qui     868
# Sex     266
# Name: dia_semana, dtype: int64

# %%
valor_conta_domingo = gorjeta.query("dia_semana == 'Dom'").valor_conta

# %%
valor_conta_sabado = gorjeta.query("dia_semana == 'Sáb'").valor_conta

# %%
ranksums(valor_conta_domingo, valor_conta_sabado)
# Out:
# RanksumsResult(statistic=3.512690684754087, pvalue=0.0004435935681441821)

# %%
gorjeta['hora_do_dia'].unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_conta', data=gorjeta)

# %%
sns.catplot(x='hora_do_dia', y='valor_conta', kind='swarm',data=gorjeta)
# Out:
# /home/jose/anaconda_/envs/alura_pandas/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 60.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jose/anaconda_/envs/alura_pandas/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 40.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='hora_do_dia', y='valor_conta', data=gorjeta)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_conta', data=gorjeta)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_conta'>

# %%
almoco = gorjeta.query("hora_do_dia == 'Almoço'").valor_conta

# %%
jantar = gorjeta.query("hora_do_dia == 'Jantar'").valor_conta

# %%
sns.histplot(almoco, kde=True)
# Out:
# <AxesSubplot:xlabel='valor_conta', ylabel='Count'>

# %%
sns.histplot(almoco, kde=False)
# Out:
# <AxesSubplot:xlabel='valor_conta', ylabel='Count'>

# %%
sns.histplot(jantar, kde=True)
# Out:
# <AxesSubplot:xlabel='valor_conta', ylabel='Count'>

# %%
ranksums(almoco, jantar)
# Out:
# RanksumsResult(statistic=-12.158511455786174, pvalue=5.169201062207143e-34)

# %%
gorjeta.groupby(['hora_do_dia']).mean()[['valor_conta', 'gorjeta', 'porcentagem']]
# Out:
#              valor_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço         17.213913  2.534495    15.779307
# Jantar         20.832954  2.779458    14.888393

# %%
porcentagem_almoco = gorjeta.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjeta.query("hora_do_dia == 'Jantar'").porcentagem

# %%
ranksums(porcentagem_almoco, porcentagem_jantar)
# Out:
# RanksumsResult(statistic=6.814330428979581, pvalue=9.470380613431753e-12)
